# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing dataset
col=["Class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids","Nonflavanoid phenols",
    "Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted wines","Proline"]
dataset=pd.read_csv("./wine.data",names=col,delimiter=",")

# %%
dataset
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
# ...

# %%
dataset.describe().transpose()
# Out:
#                               count        mean         std     min       25%  \
# Class                         178.0    1.938202    0.775035    1.00    1.0000
# Alcohol                       178.0   13.000618    0.811827   11.03   12.3625
# Malic acid                    178.0    2.336348    1.117146    0.74    1.6025
# Ash                           178.0    2.366517    0.274344    1.36    2.2100
# Alcalinity of ash             178.0   19.494944    3.339564   10.60   17.2000
# Magnesium                     178.0   99.741573   14.282484   70.00   88.0000
# Total phenols                 178.0    2.295112    0.625851    0.98    1.7425
# Flavanoids                    178.0    2.029270    0.998859    0.34    1.2050
# Nonflavanoid phenols          178.0    0.361854    0.124453    0.13    0.2700
# Proanthocyanins               178.0    1.590899    0.572359    0.41    1.2500
# Color intensity               178.0    5.058090    2.318286    1.28    3.2200
# ...

# %%
dataset.isnull().sum()
# Out:
# Class                           0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
dataset.corr()
# Out:
#                                  Class   Alcohol  Malic acid       Ash  \
# Class                         1.000000 -0.328222    0.437776 -0.049643
# Alcohol                      -0.328222  1.000000    0.094397  0.211545
# Malic acid                    0.437776  0.094397    1.000000  0.164045
# Ash                          -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash             0.517859 -0.310235    0.288500  0.443367
# Magnesium                    -0.209179  0.270798   -0.054575  0.286587
# Total phenols                -0.719163  0.289101   -0.335167  0.128980
# Flavanoids                   -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols          0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins              -0.499130  0.136698   -0.220746  0.009652
# Color intensity               0.265668  0.546364    0.248985  0.258887
# Hue                          -0.617369 -0.071747   -0.561296 -0.074667
# ...

# %%
dataset["Class"].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class, dtype: int64

# %%
sns.set(style="darkgrid")
sns.countplot(x="Class",data=dataset)

# %%
dataset.hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027B05691C88>,
# ...
#       dtype=object)

# %%
sns.scatterplot(x=dataset["Malic acid"],y=dataset["Alcohol"],hue=dataset["Class"])

# %%
sns.scatterplot(x=dataset["Malic acid"],y=dataset["Alcalinity of ash"],hue=dataset["Class"])

# %%
sns.scatterplot(x=dataset["Malic acid"],y=dataset["Hue"],hue=dataset["Class"])

# %%
y=dataset["Class"].values

# %%
x=dataset.copy()

# %%
x.drop(["Class"],axis=1,inplace=True)

# %%
x.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
x=scaler.fit_transform(x)

# %%
x
# Out:
# array([[0.84210526, 0.1916996 , 0.57219251, ..., 0.45528455, 0.97069597,
#         0.56134094],
#        [0.57105263, 0.2055336 , 0.4171123 , ..., 0.46341463, 0.78021978,
#         0.55064194],
#        [0.56052632, 0.3201581 , 0.70053476, ..., 0.44715447, 0.6959707 ,
#         0.64693295],
#        ...,
#        [0.58947368, 0.69960474, 0.48128342, ..., 0.08943089, 0.10622711,
#         0.39728959],
#        [0.56315789, 0.36561265, 0.54010695, ..., 0.09756098, 0.12820513,
#         0.40085592],
#        [0.81578947, 0.66403162, 0.73796791, ..., 0.10569106, 0.12087912,
#         0.20114123]])

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
lr=LogisticRegression()
score_lr=cross_val_score(lr,x,y,cv=10,scoring="accuracy")
plt.plot(range(1,11),score_lr)
plt.xlabel("ith cross validation")
plt.ylabel("cross_val_score")
plt.title("Logistic Regression cross validation score")
print("mean_score->",score_lr.mean())
# Out:
# mean_score-> 0.9833333333333334

# %%
knn=KNeighborsClassifier(n_neighbors=5)
score_knn=cross_val_score(knn,x,y,cv=10,scoring="accuracy")
plt.plot(range(1,11),score_knn)
plt.xlabel("ith cross validation")
plt.ylabel("cross_val_score")
plt.title("KNN cross validation score")
print("mean_score->",score_knn.mean())
# Out:
# mean_score-> 0.9604575163398692

# %%
rfc=RandomForestClassifier(n_estimators=100)
score_rfc=cross_val_score(rfc,x,y,cv=10,scoring="accuracy")
plt.plot(range(1,11),score_rfc)
plt.xlabel("ith cross validation")
plt.ylabel("cross_val_score")
plt.title("RFC cross validation score")
print("mean_score->",score_knn.mean())
# Out:
# mean_score-> 0.9604575163398692

# %%
xgb=XGBClassifier(n_estimators=100)
score_xgb=cross_val_score(xgb,x,y,cv=10,scoring="accuracy")
plt.plot(range(1,11),score_xgb)
plt.xlabel("ith cross validation")
plt.ylabel("cross_val_score")
plt.title("RFC cross validation score")
print("mean_score->",score_xgb.mean())
# Out:
# mean_score-> 0.9666666666666666

# %%
#Applying PCA
from sklearn.decomposition import PCA
pca=PCA(n_components=5)
x=pca.fit_transform(x)
explained_variance=pca.explained_variance_ratio_
print(explained_variance)
# Out:
# [0.40749485 0.18970352 0.08561671 0.07426678 0.05565301]

# %%
lr=LogisticRegression()
score_lr=cross_val_score(lr,x,y,cv=10,scoring="accuracy")
plt.plot(range(1,11),score_lr)
plt.xlabel("ith cross validation")
plt.ylabel("cross_val_score")
plt.title("Logistic Regression cross validation score after PCA")
print("mean_score->",score_lr.mean())
# Out:
# mean_score-> 0.9833333333333334

# %%
xgb=XGBClassifier(n_estimators=100)
score_xgb=cross_val_score(xgb,x,y,cv=10,scoring="accuracy")
plt.plot(range(1,11),score_xgb)
plt.xlabel("ith cross validation")
plt.ylabel("cross_val_score")
plt.title("RFC cross validation score after PCA")
print("mean_score->",score_xgb.mean())
# Out:
# mean_score-> 0.9722222222222221

# %%
knn=KNeighborsClassifier(n_neighbors=5)
score_knn=cross_val_score(knn,x,y,cv=10,scoring="accuracy")
plt.plot(range(1,11),score_knn)
plt.xlabel("ith cross validation")
plt.ylabel("cross_val_score")
plt.title("KNN cross validation score after PCA")
print("mean_score->",score_knn.mean())
# Out:
# mean_score-> 0.9774509803921569

# %%
rfc=RandomForestClassifier(n_estimators=100)
score_rfc=cross_val_score(rfc,x,y,cv=10,scoring="accuracy")
plt.plot(range(1,11),score_rfc)
plt.xlabel("ith cross validation")
plt.ylabel("cross_val_score")
plt.title("RFC cross validation score after PCA")
print("mean_score->",score_knn.mean())
# Out:
# mean_score-> 0.9774509803921569
